# %% [markdown]
# # Data Quality and Model Explainability in Computer Vision with OpenVINO™ Toolkit
#
# Understanding why computer vision models make certain predictions using data and model explainability can help us refine our models to be more efficient and performant. This tutorial demonstrates how to use data quality measurements and saliency maps to understand the predictions and performance of computer vision models during inference.
#
# The specific techniques we will cover in this kit are:
#
# **Data quality measurements**
# - Inspect the properties of data corresponding to each label (e.g., Are all the cars appearing bigger in the frame of my data (because they’re near to the camera), or are there images of cars in a distance that are smaller, so my algorithm is able to detect both near and far cars)
# - Check if the labels in the dataset are imbalanced, meaning that one label/class (“dog”, “person”) has much more data attributed to it than other labels (“cat”/”tree”).
# - Check if bounding boxes are far from the label mean, meaning that the bounding boxes that were used are incorrect.
#
# OpenVINO [datumaro](https://github.com/openvinotoolkit/datumaro/tree/develop) is a library for dataset management. We'll leverage code snippets from datumaro's tutorials, specifically on [data validation](https://github.com/openvinotoolkit/datumaro/blob/develop/notebooks/11_validate.ipynb), to generate these data quality measurements.
#
# **Saliency maps**
# - Explainability algorithms can be used to generate heatmaps or saliency maps, showing which parts of the imag  a object classification or detection model used to make a prediction.
#
#
# **Credits:** We would like to acknowledge the authors and maintainers of the Datumaro Github repository, and the Ultralytics team for their fantastic tutorials/snippets on YOLOv8.

# %% [markdown]
# ## Step 1: Download our dataset
#
# In this step, we'll download the COCO 2017 dataset, focusing specifically on the object detection task with object segmentation output. Below, we run a few commands to fetch and unzip the dataset

# %%
from zipfile import ZipFile
import sys
import os
sys.path.append("..")
import utils
import glob

from pathlib import Path

data_out_dir = Path('coco_dataset')

if Path(data_out_dir).is_dir() is not True:
    DATA_URL = "http://images.cocodataset.org/zips/val2017.zip"
    TRAIN_ANNOTATIONS_URL = "http://images.cocodataset.org/annotations/annotations_trainval2017.zip"
    PANOPTIC_ANNOTATIONS_URL = "http://images.cocodataset.org/annotations/panoptic_annotations_trainval2017.zip"
    
    utils.download_file(DATA_URL, directory=data_out_dir, show_progress=True)
    utils.download_file(TRAIN_ANNOTATIONS_URL, directory=data_out_dir, show_progress=True)
    utils.download_file(PANOPTIC_ANNOTATIONS_URL, directory=data_out_dir, show_progress=True)
    
    with ZipFile(data_out_dir / 'val2017.zip' , "r") as zip_ref:
        zip_ref.extractall(data_out_dir / 'images')
        
    with ZipFile(data_out_dir / 'annotations_trainval2017.zip' , "r") as zip_ref:
        zip_ref.extractall(data_out_dir)
    
    with ZipFile(data_out_dir / 'panoptic_annotations_trainval2017.zip' , "r") as zip_ref:
        zip_ref.extractall(data_out_dir / 'annotations')

    for filename in glob.glob('coco_dataset/**/*_train2017.json', recursive=True):
        os.remove(filename)
else:
    print("COCO Dataset folder is already present. Proceeding with next steps.")
# Out:
# COCO Dataset folder is already present. Proceeding with next steps.

# %% [markdown]
# ## Step 2: Analyze the quality of the data
#
# To start analyzing the quality of the data, we'll load in datumaro. Here, we'll import our local COCO dataseta and define our data subset as the 2017 validation data.

# %%
import datumaro as dm

dataset = dm.Dataset.import_from("coco_dataset", format="coco_instances")
subset = list(dataset.subsets().keys())[0]  # val2017
# Out:
# WARNING:root:File 'coco_dataset/annotations/person_keypoints_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/captions_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/annotations/panoptic_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances

# %%
subset
# Out:
# 'val2017'

# %%
def find_item_with_given_label_name(dataset, label_name):
    label_cats = dataset.categories()[dm.AnnotationType.label]
    for item in dataset:
        labels = {label_cats[ann.label].name for ann in item.annotations}
        if label_name in labels:
            print(f'ID: {item.id} has "{label_name}" label')

# %%
find_item_with_given_label_name(dataset, "car")
# Out:
# ID: 000000174482 has "car" label
# ID: 000000296649 has "car" label
# ID: 000000017627 has "car" label
# ID: 000000303818 has "car" label
# ID: 000000463730 has "car" label
# ID: 000000460347 has "car" label
# ID: 000000322864 has "car" label
# ID: 000000349860 has "car" label
# ID: 000000057597 has "car" label
# ID: 000000428454 has "car" label
# ID: 000000168330 has "car" label
# ID: 000000326541 has "car" label
# ID: 000000301135 has "car" label
# ID: 000000367680 has "car" label
# ID: 000000278848 has "car" label
# ID: 000000166391 has "car" label
# ID: 000000121506 has "car" label
# ID: 000000231508 has "car" label
# ID: 000000261982 has "car" label
# ID: 000000555050 has "car" label
# ID: 000000392722 has "car" label
# ID: 000000338560 has "car" label
# ID: 000000338986 has "car" label
# ID: 000000053994 has "car" label
# ID: 000000100624 has "car" label
# ID: 000000530099 has "car" label
# ID: 000000097679 has "car" label
# ID: 000000158548 has "car" label
# ID: 000000176606 has "car" label
# ID: 000000011197 has "car" label
# ID: 000000000724 has "car" label
# ID: 000000384468 has "car" label
# ID: 000000113235 has "car" label
# ID: 000000260470 has "car" label
# ID: 000000297578 has "car" label
# ID: 000000038048 has "car" label
# ID: 000000354829 has "car" label
# ID: 000000561679 has "car" label
# ID: 000000379800 has "car" label
# ID: 000000334006 has "car" label
# ID: 000000414385 has "car" label
# ID: 000000432898 has "car" label
# ID: 000000163057 has "car" label
# ID: 000000290179 has "car" label
# ID: 000000054593 has "car" label
# ID: 000000410880 has "car" label
# ID: 000000074058 has "car" label
# ID: 000000210273 has "car" label
# ID: 000000446651 has "car" label
# ID: 000000008762 has "car" label
# ID: 000000526392 has "car" label
# ID: 000000165039 has "car" label
# ID: 000000323828 has "car" label
# ID: 000000334555 has "car" label
# ID: 000000196759 has "car" label
# ID: 000000047828 has "car" label
# ID: 000000421455 has "car" label
# ID: 000000506656 has "car" label
# ID: 000000567640 has "car" label
# ID: 000000395801 has "car" label
# ID: 000000259690 has "car" label
# ID: 000000343218 has "car" label
# ID: 000000308531 has "car" label
# ID: 000000191013 has "car" label
# ID: 000000177934 has "car" label
# ID: 000000134886 has "car" label
# ID: 000000310072 has "car" label
# ID: 000000087144 has "car" label
# ID: 000000042070 has "car" label
# ID: 000000296224 has "car" label
# ID: 000000389566 has "car" label
# ID: 000000225532 has "car" label
# ID: 000000338624 has "car" label
# ID: 000000263463 has "car" label
# ID: 000000169996 has "car" label
# ID: 000000226417 has "car" label
# ID: 000000493286 has "car" label
# ID: 000000230008 has "car" label
# ID: 000000456394 has "car" label
# ID: 000000284445 has "car" label
# ID: 000000468124 has "car" label
# ID: 000000273198 has "car" label
# ID: 000000417779 has "car" label
# ID: 000000447342 has "car" label
# ID: 000000214200 has "car" label
# ID: 000000369751 has "car" label
# ID: 000000429011 has "car" label
# ID: 000000025393 has "car" label
# ID: 000000130699 has "car" label
# ID: 000000537506 has "car" label
# ID: 000000334309 has "car" label
# ID: 000000089556 has "car" label
# ID: 000000086220 has "car" label
# ID: 000000508602 has "car" label
# ID: 000000010363 has "car" label
# ID: 000000017178 has "car" label
# ID: 000000507975 has "car" label
# ID: 000000313182 has "car" label
# ID: 000000538364 has "car" label
# ID: 000000015338 has "car" label
# ID: 000000512564 has "car" label
# ID: 000000336658 has "car" label
# ID: 000000476704 has "car" label
# ID: 000000260266 has "car" label
# ID: 000000177893 has "car" label
# ID: 000000315450 has "car" label
# ID: 000000243867 has "car" label
# ID: 000000263594 has "car" label
# ID: 000000147725 has "car" label
# ID: 000000138979 has "car" label
# ID: 000000100283 has "car" label
# ID: 000000563653 has "car" label
# ID: 000000345361 has "car" label
# ID: 000000086483 has "car" label
# ID: 000000521141 has "car" label
# ID: 000000393093 has "car" label
# ID: 000000126592 has "car" label
# ID: 000000521052 has "car" label
# ID: 000000460147 has "car" label
# ID: 000000069356 has "car" label
# ID: 000000514586 has "car" label
# ID: 000000183709 has "car" label
# ID: 000000057672 has "car" label
# ID: 000000138639 has "car" label
# ID: 000000139099 has "car" label
# ID: 000000221754 has "car" label
# ID: 000000274272 has "car" label
# ID: 000000127092 has "car" label
# ID: 000000507797 has "car" label
# ID: 000000146498 has "car" label
# ID: 000000511999 has "car" label
# ID: 000000488664 has "car" label
# ID: 000000407083 has "car" label
# ID: 000000394206 has "car" label
# ID: 000000437239 has "car" label
# ID: 000000382111 has "car" label
# ID: 000000394510 has "car" label
# ID: 000000160728 has "car" label
# ID: 000000342128 has "car" label
# ID: 000000427055 has "car" label
# ID: 000000152771 has "car" label
# ID: 000000309391 has "car" label
# ID: 000000480944 has "car" label
# ID: 000000542423 has "car" label
# ID: 000000344909 has "car" label
# ID: 000000523241 has "car" label
# ID: 000000067616 has "car" label
# ID: 000000258793 has "car" label
# ID: 000000433774 has "car" label
# ID: 000000488251 has "car" label
# ID: 000000107554 has "car" label
# ID: 000000196141 has "car" label
# ID: 000000461751 has "car" label
# ID: 000000567197 has "car" label
# ID: 000000498286 has "car" label
# ID: 000000206487 has "car" label
# ID: 000000565012 has "car" label
# ID: 000000427500 has "car" label
# ID: 000000213605 has "car" label
# ID: 000000496722 has "car" label
# ID: 000000105923 has "car" label
# ID: 000000166664 has "car" label
# ID: 000000212573 has "car" label
# ID: 000000319369 has "car" label
# ID: 000000050679 has "car" label
# ID: 000000278705 has "car" label
# ID: 000000188296 has "car" label
# ID: 000000511760 has "car" label
# ID: 000000078823 has "car" label
# ID: 000000527220 has "car" label
# ID: 000000315187 has "car" label
# ID: 000000076417 has "car" label
# ID: 000000439623 has "car" label
# ID: 000000436883 has "car" label
# ID: 000000459500 has "car" label
# ID: 000000338718 has "car" label
# ID: 000000442456 has "car" label
# ID: 000000046872 has "car" label
# ID: 000000442746 has "car" label
# ID: 000000381971 has "car" label
# ID: 000000344888 has "car" label
# ID: 000000045596 has "car" label
# ID: 000000172330 has "car" label
# ID: 000000319607 has "car" label
# ID: 000000201934 has "car" label
# ID: 000000441468 has "car" label
# ID: 000000277005 has "car" label
# ID: 000000130386 has "car" label
# ID: 000000534639 has "car" label
# ID: 000000266981 has "car" label
# ID: 000000184611 has "car" label
# ID: 000000017029 has "car" label
# ID: 000000227898 has "car" label
# ID: 000000350148 has "car" label
# ID: 000000301421 has "car" label
# ID: 000000425925 has "car" label
# ID: 000000356424 has "car" label
# ID: 000000030828 has "car" label
# ID: 000000492077 has "car" label
# ID: 000000357737 has "car" label
# ID: 000000365642 has "car" label
# ID: 000000520009 has "car" label
# ID: 000000410712 has "car" label
# ID: 000000474164 has "car" label
# ID: 000000356612 has "car" label
# ID: 000000055150 has "car" label
# ID: 000000132544 has "car" label
# ID: 000000411938 has "car" label
# ID: 000000560474 has "car" label
# ID: 000000380706 has "car" label
# ID: 000000136715 has "car" label
# ID: 000000162858 has "car" label
# ID: 000000255917 has "car" label
# ID: 000000232538 has "car" label
# ID: 000000303908 has "car" label
# ID: 000000098392 has "car" label
# ID: 000000142472 has "car" label
# ID: 000000369442 has "car" label
# ID: 000000213593 has "car" label
# ID: 000000495146 has "car" label
# ID: 000000391290 has "car" label
# ID: 000000419408 has "car" label
# ID: 000000532481 has "car" label
# ID: 000000398742 has "car" label
# ID: 000000545100 has "car" label
# ID: 000000577932 has "car" label
# ID: 000000067213 has "car" label
# ID: 000000181816 has "car" label
# ID: 000000283318 has "car" label
# ID: 000000278749 has "car" label
# ID: 000000566282 has "car" label
# ID: 000000408120 has "car" label
# ID: 000000198489 has "car" label
# ID: 000000397351 has "car" label
# ID: 000000144333 has "car" label
# ID: 000000515266 has "car" label
# ID: 000000107087 has "car" label
# ID: 000000141597 has "car" label
# ID: 000000480021 has "car" label
# ID: 000000558558 has "car" label
# ID: 000000373353 has "car" label
# ID: 000000336232 has "car" label
# ID: 000000017207 has "car" label
# ID: 000000498709 has "car" label
# ID: 000000361142 has "car" label
# ID: 000000209222 has "car" label
# ID: 000000500613 has "car" label
# ID: 000000057149 has "car" label
# ID: 000000155341 has "car" label
# ID: 000000478474 has "car" label
# ID: 000000172648 has "car" label
# ID: 000000521259 has "car" label
# ID: 000000127263 has "car" label
# ID: 000000230983 has "car" label
# ID: 000000433515 has "car" label
# ID: 000000549738 has "car" label
# ID: 000000466416 has "car" label
# ID: 000000228436 has "car" label
# ID: 000000463037 has "car" label
# ID: 000000215723 has "car" label
# ID: 000000464824 has "car" label
# ID: 000000161128 has "car" label
# ID: 000000514376 has "car" label
# ID: 000000236845 has "car" label
# ID: 000000515025 has "car" label
# ID: 000000151962 has "car" label
# ID: 000000458325 has "car" label
# ID: 000000213255 has "car" label
# ID: 000000180878 has "car" label
# ID: 000000208423 has "car" label
# ID: 000000553669 has "car" label
# ID: 000000365207 has "car" label
# ID: 000000400367 has "car" label
# ID: 000000350023 has "car" label
# ID: 000000142585 has "car" label
# ID: 000000499768 has "car" label
# ID: 000000293071 has "car" label
# ID: 000000192716 has "car" label
# ID: 000000137727 has "car" label
# ID: 000000580418 has "car" label
# ID: 000000577976 has "car" label
# ID: 000000546823 has "car" label
# ID: 000000426203 has "car" label
# ID: 000000084492 has "car" label
# ID: 000000125778 has "car" label
# ID: 000000530470 has "car" label
# ID: 000000105455 has "car" label
# ID: 000000167122 has "car" label
# ID: 000000490936 has "car" label
# ID: 000000287291 has "car" label
# ID: 000000006040 has "car" label
# ID: 000000378139 has "car" label
# ID: 000000200961 has "car" label
# ID: 000000121242 has "car" label
# ID: 000000427655 has "car" label
# ID: 000000065350 has "car" label
# ID: 000000357816 has "car" label
# ID: 000000457884 has "car" label
# ID: 000000506707 has "car" label
# ID: 000000363188 has "car" label
# ID: 000000228942 has "car" label
# ID: 000000065485 has "car" label
# ID: 000000084752 has "car" label
# ID: 000000021839 has "car" label
# ID: 000000155451 has "car" label
# ID: 000000032941 has "car" label
# ID: 000000517069 has "car" label
# ID: 000000453841 has "car" label
# ID: 000000022755 has "car" label
# ID: 000000283037 has "car" label
# ID: 000000244379 has "car" label
# ID: 000000344029 has "car" label
# ID: 000000542625 has "car" label
# ID: 000000566758 has "car" label
# ID: 000000369812 has "car" label
# ID: 000000565563 has "car" label
# ID: 000000335177 has "car" label
# ID: 000000393226 has "car" label
# ID: 000000355240 has "car" label
# ID: 000000032334 has "car" label
# ID: 000000295809 has "car" label
# ID: 000000424162 has "car" label
# ID: 000000376284 has "car" label
# ID: 000000462756 has "car" label
# ID: 000000307074 has "car" label
# ID: 000000211674 has "car" label
# ID: 000000124798 has "car" label
# ID: 000000297681 has "car" label
# ID: 000000572303 has "car" label
# ID: 000000283038 has "car" label
# ID: 000000230450 has "car" label
# ID: 000000568147 has "car" label
# ID: 000000346232 has "car" label
# ID: 000000102805 has "car" label
# ID: 000000245320 has "car" label
# ID: 000000416885 has "car" label
# ID: 000000292997 has "car" label
# ID: 000000240940 has "car" label
# ID: 000000198928 has "car" label
# ID: 000000343496 has "car" label
# ID: 000000147338 has "car" label
# ID: 000000276720 has "car" label
# ID: 000000014380 has "car" label
# ID: 000000458702 has "car" label
# ID: 000000413689 has "car" label
# ID: 000000313588 has "car" label
# ID: 000000361506 has "car" label
# ID: 000000119911 has "car" label
# ID: 000000274411 has "car" label
# ID: 000000064523 has "car" label
# ID: 000000224051 has "car" label
# ID: 000000061108 has "car" label
# ID: 000000058539 has "car" label
# ID: 000000418696 has "car" label
# ID: 000000181542 has "car" label
# ID: 000000146667 has "car" label
# ID: 000000044590 has "car" label
# ID: 000000543043 has "car" label
# ID: 000000094751 has "car" label
# ID: 000000284725 has "car" label
# ID: 000000105912 has "car" label
# ID: 000000568290 has "car" label
# ID: 000000366178 has "car" label
# ID: 000000176037 has "car" label
# ID: 000000528980 has "car" label
# ID: 000000575243 has "car" label
# ID: 000000007088 has "car" label
# ID: 000000396200 has "car" label
# ID: 000000289938 has "car" label
# ID: 000000135604 has "car" label
# ID: 000000111036 has "car" label
# ID: 000000433204 has "car" label
# ID: 000000224724 has "car" label
# ID: 000000001532 has "car" label
# ID: 000000354753 has "car" label
# ID: 000000511076 has "car" label
# ID: 000000343976 has "car" label
# ID: 000000507667 has "car" label
# ID: 000000491464 has "car" label
# ID: 000000227511 has "car" label
# ID: 000000491213 has "car" label
# ID: 000000553511 has "car" label
# ID: 000000170545 has "car" label
# ID: 000000269942 has "car" label
# ID: 000000109441 has "car" label
# ID: 000000079034 has "car" label
# ID: 000000026926 has "car" label
# ID: 000000499775 has "car" label
# ID: 000000276707 has "car" label
# ID: 000000184324 has "car" label
# ID: 000000476119 has "car" label
# ID: 000000281687 has "car" label
# ID: 000000273420 has "car" label
# ID: 000000297562 has "car" label
# ID: 000000260925 has "car" label
# ID: 000000193717 has "car" label
# ID: 000000484029 has "car" label
# ID: 000000424975 has "car" label
# ID: 000000323571 has "car" label
# ID: 000000081394 has "car" label
# ID: 000000377946 has "car" label
# ID: 000000449312 has "car" label
# ID: 000000470924 has "car" label
# ID: 000000194716 has "car" label
# ID: 000000144706 has "car" label
# ID: 000000454661 has "car" label
# ID: 000000183246 has "car" label
# ID: 000000303305 has "car" label
# ID: 000000179265 has "car" label
# ID: 000000338625 has "car" label
# ID: 000000356169 has "car" label
# ID: 000000553339 has "car" label
# ID: 000000414133 has "car" label
# ID: 000000475484 has "car" label
# ID: 000000198805 has "car" label
# ID: 000000041633 has "car" label
# ID: 000000526728 has "car" label
# ID: 000000192670 has "car" label
# ID: 000000301376 has "car" label
# ID: 000000368335 has "car" label
# ID: 000000276284 has "car" label
# ID: 000000085376 has "car" label
# ID: 000000569030 has "car" label
# ID: 000000039484 has "car" label
# ID: 000000505942 has "car" label
# ID: 000000396338 has "car" label
# ID: 000000372260 has "car" label
# ID: 000000114770 has "car" label
# ID: 000000165681 has "car" label
# ID: 000000147740 has "car" label
# ID: 000000485237 has "car" label
# ID: 000000404479 has "car" label
# ID: 000000438017 has "car" label
# ID: 000000550691 has "car" label
# ID: 000000169169 has "car" label
# ID: 000000124277 has "car" label
# ID: 000000426268 has "car" label
# ID: 000000309964 has "car" label
# ID: 000000177861 has "car" label
# ID: 000000157365 has "car" label
# ID: 000000570688 has "car" label
# ID: 000000555597 has "car" label
# ID: 000000027768 has "car" label
# ID: 000000204871 has "car" label
# ID: 000000088462 has "car" label
# ID: 000000320232 has "car" label
# ID: 000000006723 has "car" label
# ID: 000000289594 has "car" label
# ID: 000000135410 has "car" label
# ID: 000000426372 has "car" label
# ID: 000000521819 has "car" label
# ID: 000000513567 has "car" label
# ID: 000000033221 has "car" label
# ID: 000000158744 has "car" label
# ID: 000000160012 has "car" label
# ID: 000000175438 has "car" label
# ID: 000000033854 has "car" label
# ID: 000000052412 has "car" label
# ID: 000000068093 has "car" label
# ID: 000000314251 has "car" label
# ID: 000000026204 has "car" label
# ID: 000000423617 has "car" label
# ID: 000000084170 has "car" label
# ID: 000000564336 has "car" label
# ID: 000000350003 has "car" label
# ID: 000000033109 has "car" label
# ID: 000000295420 has "car" label
# ID: 000000009891 has "car" label
# ID: 000000293794 has "car" label
# ID: 000000378673 has "car" label
# ID: 000000043737 has "car" label
# ID: 000000222094 has "car" label
# ID: 000000329614 has "car" label
# ID: 000000156071 has "car" label
# ID: 000000474452 has "car" label
# ID: 000000463849 has "car" label
# ID: 000000324158 has "car" label
# ID: 000000468332 has "car" label
# ID: 000000383289 has "car" label
# ID: 000000430048 has "car" label
# ID: 000000412531 has "car" label
# ID: 000000579902 has "car" label
# ID: 000000327890 has "car" label
# ID: 000000539445 has "car" label
# ID: 000000100274 has "car" label
# ID: 000000479030 has "car" label
# ID: 000000018837 has "car" label
# ID: 000000153011 has "car" label
# ID: 000000242411 has "car" label
# ID: 000000122166 has "car" label
# ID: 000000565391 has "car" label
# ID: 000000115946 has "car" label
# ID: 000000436738 has "car" label
# ID: 000000226802 has "car" label
# ID: 000000148508 has "car" label
# ID: 000000326627 has "car" label
# ID: 000000303566 has "car" label
# ID: 000000146831 has "car" label
# ID: 000000414510 has "car" label
# ID: 000000102411 has "car" label
# ID: 000000254814 has "car" label
# ID: 000000055167 has "car" label
# ID: 000000005037 has "car" label
# ID: 000000147223 has "car" label
# ID: 000000269632 has "car" label
# ID: 000000220732 has "car" label
# ID: 000000386210 has "car" label
# ID: 000000031118 has "car" label
# ID: 000000157756 has "car" label
# ID: 000000466156 has "car" label
# ID: 000000111086 has "car" label
# ID: 000000429109 has "car" label
# ID: 000000334371 has "car" label
# ID: 000000054967 has "car" label
# ID: 000000128372 has "car" label
# ID: 000000404534 has "car" label
# ID: 000000499181 has "car" label
# ID: 000000093154 has "car" label
# ID: 000000376625 has "car" label
# ID: 000000082821 has "car" label
# ID: 000000305695 has "car" label
# ID: 000000513181 has "car" label
# ID: 000000157928 has "car" label
# ID: 000000171382 has "car" label
# ID: 000000504415 has "car" label
# ID: 000000023272 has "car" label
# ID: 000000059386 has "car" label
# ID: 000000279714 has "car" label
# ID: 000000341921 has "car" label
# ID: 000000019042 has "car" label
# ID: 000000534394 has "car" label
# ID: 000000477227 has "car" label
# ID: 000000040083 has "car" label
# ID: 000000478721 has "car" label
# ID: 000000033759 has "car" label

# %%
dataset = dataset.filter('/item/annotation[label="car" or label="bus" or label="train" or label="truck" or label="street sign" or label="road street" or label="stop sign" or label="traffic light" or label="license plate"]', filter_annotations=True)

# %%
find_item_with_given_label_name(dataset, "bus")
# Out:
# ID: 000000017627 has "bus" label
# ID: 000000143931 has "bus" label
# ID: 000000303818 has "bus" label
# ID: 000000463730 has "bus" label
# ID: 000000460347 has "bus" label
# ID: 000000233771 has "bus" label
# ID: 000000367680 has "bus" label
# ID: 000000278848 has "bus" label
# ID: 000000338428 has "bus" label
# ID: 000000392722 has "bus" label
# ID: 000000570539 has "bus" label
# ID: 000000259571 has "bus" label
# ID: 000000290179 has "bus" label
# ID: 000000210273 has "bus" label
# ID: 000000255749 has "bus" label
# ID: 000000165039 has "bus" label
# ID: 000000259690 has "bus" label
# ID: 000000289222 has "bus" label
# ID: 000000042070 has "bus" label
# ID: 000000296224 has "bus" label
# ID: 000000122606 has "bus" label
# ID: 000000311909 has "bus" label
# ID: 000000263463 has "bus" label
# ID: 000000284445 has "bus" label
# ID: 000000468124 has "bus" label
# ID: 000000187144 has "bus" label
# ID: 000000095843 has "bus" label
# ID: 000000447342 has "bus" label
# ID: 000000086220 has "bus" label
# ID: 000000313182 has "bus" label
# ID: 000000015338 has "bus" label
# ID: 000000512564 has "bus" label
# ID: 000000336658 has "bus" label
# ID: 000000568439 has "bus" label
# ID: 000000372317 has "bus" label
# ID: 000000476704 has "bus" label
# ID: 000000106048 has "bus" label
# ID: 000000177893 has "bus" label
# ID: 000000315450 has "bus" label
# ID: 000000243867 has "bus" label
# ID: 000000147725 has "bus" label
# ID: 000000138979 has "bus" label
# ID: 000000460147 has "bus" label
# ID: 000000194832 has "bus" label
# ID: 000000274272 has "bus" label
# ID: 000000507797 has "bus" label
# ID: 000000309391 has "bus" label
# ID: 000000480944 has "bus" label
# ID: 000000488251 has "bus" label
# ID: 000000074256 has "bus" label
# ID: 000000206487 has "bus" label
# ID: 000000455085 has "bus" label
# ID: 000000542856 has "bus" label
# ID: 000000015517 has "bus" label
# ID: 000000213605 has "bus" label
# ID: 000000563604 has "bus" label
# ID: 000000144300 has "bus" label
# ID: 000000315187 has "bus" label
# ID: 000000196843 has "bus" label
# ID: 000000436883 has "bus" label
# ID: 000000319607 has "bus" label
# ID: 000000201934 has "bus" label
# ID: 000000353180 has "bus" label
# ID: 000000423519 has "bus" label
# ID: 000000516804 has "bus" label
# ID: 000000266981 has "bus" label
# ID: 000000492077 has "bus" label
# ID: 000000520009 has "bus" label
# ID: 000000362682 has "bus" label
# ID: 000000356612 has "bus" label
# ID: 000000380706 has "bus" label
# ID: 000000076416 has "bus" label
# ID: 000000531036 has "bus" label
# ID: 000000098392 has "bus" label
# ID: 000000142472 has "bus" label
# ID: 000000516143 has "bus" label
# ID: 000000319534 has "bus" label
# ID: 000000460967 has "bus" label
# ID: 000000052007 has "bus" label
# ID: 000000373353 has "bus" label
# ID: 000000336232 has "bus" label
# ID: 000000017207 has "bus" label
# ID: 000000363875 has "bus" label
# ID: 000000306136 has "bus" label
# ID: 000000389684 has "bus" label
# ID: 000000057149 has "bus" label
# ID: 000000336628 has "bus" label
# ID: 000000125572 has "bus" label
# ID: 000000171298 has "bus" label
# ID: 000000443498 has "bus" label
# ID: 000000365655 has "bus" label
# ID: 000000161128 has "bus" label
# ID: 000000514376 has "bus" label
# ID: 000000463199 has "bus" label
# ID: 000000350023 has "bus" label
# ID: 000000142585 has "bus" label
# ID: 000000574425 has "bus" label
# ID: 000000128051 has "bus" label
# ID: 000000509008 has "bus" label
# ID: 000000347544 has "bus" label
# ID: 000000090208 has "bus" label
# ID: 000000427655 has "bus" label
# ID: 000000445834 has "bus" label
# ID: 000000350122 has "bus" label
# ID: 000000032941 has "bus" label
# ID: 000000022755 has "bus" label
# ID: 000000562448 has "bus" label
# ID: 000000545219 has "bus" label
# ID: 000000344029 has "bus" label
# ID: 000000359937 has "bus" label
# ID: 000000566758 has "bus" label
# ID: 000000369812 has "bus" label
# ID: 000000110784 has "bus" label
# ID: 000000211674 has "bus" label
# ID: 000000124798 has "bus" label
# ID: 000000114884 has "bus" label
# ID: 000000387387 has "bus" label
# ID: 000000253002 has "bus" label
# ID: 000000198928 has "bus" label
# ID: 000000082846 has "bus" label
# ID: 000000454798 has "bus" label
# ID: 000000181542 has "bus" label
# ID: 000000543043 has "bus" label
# ID: 000000284725 has "bus" label
# ID: 000000105912 has "bus" label
# ID: 000000568290 has "bus" label
# ID: 000000484404 has "bus" label
# ID: 000000233727 has "bus" label
# ID: 000000176037 has "bus" label
# ID: 000000449432 has "bus" label
# ID: 000000377723 has "bus" label
# ID: 000000200839 has "bus" label
# ID: 000000001584 has "bus" label
# ID: 000000499775 has "bus" label
# ID: 000000184324 has "bus" label
# ID: 000000550349 has "bus" label
# ID: 000000210394 has "bus" label
# ID: 000000377946 has "bus" label
# ID: 000000454661 has "bus" label
# ID: 000000303305 has "bus" label
# ID: 000000179265 has "bus" label
# ID: 000000338625 has "bus" label
# ID: 000000203294 has "bus" label
# ID: 000000405205 has "bus" label
# ID: 000000550691 has "bus" label
# ID: 000000452321 has "bus" label
# ID: 000000027768 has "bus" label
# ID: 000000204871 has "bus" label
# ID: 000000088462 has "bus" label
# ID: 000000006723 has "bus" label
# ID: 000000033854 has "bus" label
# ID: 000000026204 has "bus" label
# ID: 000000202339 has "bus" label
# ID: 000000355817 has "bus" label
# ID: 000000357748 has "bus" label
# ID: 000000415536 has "bus" label
# ID: 000000423617 has "bus" label
# ID: 000000084170 has "bus" label
# ID: 000000033109 has "bus" label
# ID: 000000329614 has "bus" label
# ID: 000000293324 has "bus" label
# ID: 000000446206 has "bus" label
# ID: 000000249219 has "bus" label
# ID: 000000474452 has "bus" label
# ID: 000000280710 has "bus" label
# ID: 000000534673 has "bus" label
# ID: 000000153011 has "bus" label
# ID: 000000540414 has "bus" label
# ID: 000000524850 has "bus" label
# ID: 000000436738 has "bus" label
# ID: 000000226802 has "bus" label
# ID: 000000148508 has "bus" label
# ID: 000000254814 has "bus" label
# ID: 000000055167 has "bus" label
# ID: 000000005037 has "bus" label
# ID: 000000147223 has "bus" label
# ID: 000000269632 has "bus" label
# ID: 000000333402 has "bus" label
# ID: 000000497867 has "bus" label
# ID: 000000133819 has "bus" label
# ID: 000000002006 has "bus" label
# ID: 000000220732 has "bus" label
# ID: 000000333745 has "bus" label
# ID: 000000429109 has "bus" label
# ID: 000000334371 has "bus" label
# ID: 000000128372 has "bus" label
# ID: 000000015440 has "bus" label
# ID: 000000226154 has "bus" label
# ID: 000000394275 has "bus" label

# %%
def get_ids(dataset: dm.Dataset, subset: str):
    ids = []
    for item in dataset:
        if item.subset == subset:
            ids += [item.id]

    return ids


ids = get_ids(dataset, subset)
print("DatasetItem ids:", ids[:4])
# Out:
# DatasetItem ids: ['000000397133', '000000037777', '000000252219', '000000087038']

# %% [markdown]
# Let's start with briefly visualizing our data and the ground truth bounding boxes and semantic segmentation coming with the dataset.

# %%
visualizer = dm.Visualizer(dataset, figsize=(16, 12), alpha=0.7)

fig = visualizer.vis_one_sample(ids[55], subset)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 visualizer = dm.Visualizer(dataset, figsize=(16, 12), alpha=0.7)
#       3 fig = visualizer.vis_one_sample(ids[55], subset)
#       4 fig.show()
#
# AttributeError: module 'datumaro' has no attribute 'Visualizer'

# %% [markdown]
# ## Step 2: Create an automated data quality report
# Via datumaro's Visualizer, we can now see the outputs on a few images from the data. Let's now take a look at creating a validation report.

# %%
from datumaro.plugins.validators import DetectionValidator

extra_args = {
    "few_samples_thr": 100,
    "imbalance_ratio_thr": 5,
    "far_from_mean_thr": 20.0,
}

validator = DetectionValidator(**extra_args)

#Defining a function to create a summary validation report of the data
def validate(dataset):
    reports = validator.validate(dataset)

    print("Validation report summary:", reports["summary"])

    error_cnt = {}
    warning_cnt = {}
    for report in reports["validation_reports"]:
        if report["severity"] == "error":
            type = report["anomaly_type"]
            if error_cnt.get(type) is None:
                error_cnt[type] = 1
            else:
                error_cnt[type] += 1
        if report["severity"] == "warning":
            type = report["anomaly_type"]
            if warning_cnt.get(type) is None:
                warning_cnt[type] = 1
            else:
                warning_cnt[type] += 1
    print("The number of errors per error type: ", error_cnt)
    print("The number of warnings per warning type: ", warning_cnt)

    return reports


reports = validate(dataset)
# Out:
# Validation report summary: {'errors': 3534, 'warnings': 4175}
# The number of errors per error type:  {'UndefinedAttribute': 3534}
# The number of warnings per warning type:  {'MissingAnnotation': 4091, 'LabelDefinedButNotFound': 74, 'FewSamplesInLabel': 1, 'ImbalancedLabels': 1, 'ImbalancedDistInLabel': 7, 'FarFromLabelMean': 1}

# %% [markdown]
# ## Step 3 Treat data errors (selected)
#
# Looking deeper into the metadata of the MS-COCO datasset subset, we can pinpoint the UndefineAttribute errors are due to the attribute is_crowd not being defined in metadata.
#
# Let's try treating the UndefinedAttribute errors by rejecting these specific labels from annotations in the sample.

# %%
from datumaro.components.annotation import AnnotationType, LabelCategories

label_categories = dataset.categories().get(AnnotationType.label, LabelCategories())

for report in reports["validation_reports"]:
    if report["anomaly_type"] == "UndefinedAttribute":
        item = dataset.get(report["item_id"], report["subset"])
        for ann in item.annotations:
            for k in ann.attributes.keys():
                label_categories[ann.label].attributes.add(k)

reports = validate(dataset)
# Out:
# Validation report summary: {'errors': 0, 'warnings': 4198}
# The number of errors per error type:  {}
# The number of warnings per warning type:  {'MissingAnnotation': 4091, 'LabelDefinedButNotFound': 74, 'FewSamplesInLabel': 1, 'ImbalancedLabels': 1, 'FewSamplesInAttribute': 5, 'ImbalancedAttribute': 4, 'ImbalancedDistInLabel': 7, 'ImbalancedDistInAttribute': 12, 'FarFromLabelMean': 1, 'OnlyOneAttributeValue': 2}

# %% [markdown]
# It looks like that specific category of issues is fixed! Let's now specifically look into the warnings section, and dive deeper there.

# %% [markdown]
# ## Step 4: Visualize data warnings
#
# Here, we'll define a sample function to visualize our data warnings.

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from datumaro.components.annotation import AnnotationType, LabelCategories

label_categories = dataset.categories().get(AnnotationType.label, LabelCategories())

#Defining a function to visualize label IDs
def visualize_label_id(item, label_id=None):
    img = item.media.data.astype(np.uint8)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    for ann in item.annotations:
        if not label_id:
            continue
        if ann.id == label_id:
            x, y, w, h = ann.get_bbox()
            label_name = label_categories[ann.label].name
            x1, y1, x2, y2 = int(x), int(y), int(x + w), int(y + h)
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 1)
            cv2.putText(img, label_name, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0))

    plt.imshow(img)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### 4.1 Imbalanced Labels
#
# Let's start with imbalanced labels. The number of objects per label measures the distribution of the data objects across different categories or classes. We can review this metric to identify if the number of objects per label is skewed or uneven beyond expectations, in which case the data might not represent the real-world distribution of the categories.

# %%
for report in reports["validation_reports"]:
    if report["anomaly_type"] == "ImbalancedLabels":
        print(report["description"])

stats = reports["statistics"]

label_stats = stats["label_distribution"]["defined_labels"]
label_name, label_counts = zip(*[(k, v) for k, v in label_stats.items()])

plt.figure(figsize=(12, 4))
plt.hist(label_name[:20], weights=label_counts[:20], bins=len(label_name[:20]))
plt.xticks(rotation="vertical")
plt.show()
# Out:
# There is an imbalance in the label distribution.

# %% [markdown]
# Taking a look at the above plot, we can identify that there's a much higher number of labels corresponding to the "car" category compared to other labels. We also see a smaller number of labels to data allocated to the stop sign label for example, which implies that our downstream model performance could be lower on this particular category.
#
# If high performance on these categories with lower amounts of data is important to us for our use case, we may consider gathering and adding additional data for these categories as our next step.

# %% [markdown]
# ### 4.2 Missing Annotations
#
# Data samples with missing annotations can be problematic for the performance of a model. Although being a part of the dataset, these data samples are completely invaluable due to missing annotations that the model cannot leverage for training, or for evaluation during inference.

# %%
missing_annotations = []
for report in reports["validation_reports"]:
    if report["anomaly_type"] == "MissingAnnotation":
        missing_annotations.append(dataset.get(report["item_id"], report["subset"]))

visualize_label_id(missing_annotations[55])

# %% [markdown]
# ### 4.3 FarFromLabelMean
#
# Far From Label Mean measures the variation of the size of bounding boxes objects in our dataset used for AI applications.
# We can visualize the object size corresponding to each label, including the overall height and width of objects in relation to each other.
#
# When annotating images, the ground truth bounding boxes are typically created to snap around individuals’ figures,  with all of the object size results being balanced.
#
# However, in certain cases, we can have anomalous bounding boxes that are too thin or too tall, and don't accurately capture the object as part of the dataset.

# %%
for report in reports["validation_reports"]:
    if report["anomaly_type"] == "FarFromLabelMean":
        print(report["description"])
        item = dataset.get(report["item_id"], report["subset"])
        label_id = [int(s) for s in str.split(report["description"], "'") if s.isdigit()][0]
        visualize_label_id(item, label_id)
# Out:
# Annotation '900300121242' in the item has a value of 'bounding box ratio(w/h)' that is too far from the label average. (mean of 'car' label: 1.67, got '29.29').

# %% [markdown]
# In some special cases like the above instance, we can pinpoint multiple issues: Here, not only is the bounding box stretched incorrectly, this is also not an image of a car! We could either manually delete this image, or adjust the ground truth annotation label and bounding box to make it usable.

# %% [markdown]
# ## Generate a heatmap for model explainability
#
# For many different use cases, we'll want to leverage optimized object detection models with a smaller model footprint and faster inference. But can we also add explainability to these optimized models?
#
# Let's explore this with using the OpenVINO™ YOLOv8 model FP16 model via the Ultralytics API. Ultralytics' YOLOv8 API provides convenient model exporting to different formats, including OpenVINO IR. model.export is responsible for the model conversion. We need to specify the format, and additionally, we could preserve dynamic shapes in the model. It would limit us to use CPU only, so we're not doing this. Also, we specify we want to use half-precision (FP16) to get better performance.

# %%
from ultralytics import YOLO

#Specify our models path
models_dir = Path('./model')
models_dir.mkdir(exist_ok=True)

DET_MODEL_NAME = "yolov8m"
det_model = YOLO(models_dir / f'{DET_MODEL_NAME}.pt')
label_map = det_model.model.names

# Load our Yolov8 object detection model
ov_model_path = Path(f"model/{DET_MODEL_NAME}_openvino_model/{DET_MODEL_NAME}.xml")
if not ov_model_path.exists():
    # export model to OpenVINO format
    out_dir = det_model.export(format="openvino", dynamic=False, half=True)

model = YOLO('model/yolov8m_openvino_model/')
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at '/home/adrian/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %% [markdown]
# Next, let's generate a heatmap with the Ultralytics YOLOv8 API and Intel OpenVINO.
#
# For object classification and detection models, a **heatmap**, or **saliency map**, shows where a model is "focusing" on a certain part of the image to make a prediction/inference. Higher intensities of color indicate a greater focus than the model is placing on that part of the image, and cooler tones indicate a lower focus, pertaining to the detected object.
#
# Let's consider an example of a sample video of cars, with footage from an aerial drone.

# %%
#Source: https://docs.ultralytics.com/guides/heatmaps/#real-world-applications

from ultralytics import YOLO
from ultralytics.solutions import heatmap
import cv2

model = YOLO('model/yolov8m_openvino_model/')
cap = cv2.VideoCapture("data/Cars-FHD.mov")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("heatmap_output.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               fps,
                               (w, h))

# Init heatmap
heatmap_obj = heatmap.Heatmap(colormap=cv2.COLORMAP_PARULA,
                     imw=w,
                     imh=h,
                     show=True,
                      model = 'model/yolov8m_openvino_model/')

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    im0 = heatmap_obj.generate_heatmap(im0)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': 12, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'imw': 1920, 'imh': 1080, 'show': True, 'model': 'model/yolov8m_openvino_model/'}
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading model/yolov8m_openvino_model for OpenVINO inference...
# Using OpenVINO CUMULATIVE_THROUGHPUT mode for batch=16 inference...
# /home/adrian/repos/openvino_build_deploy/ai_ref_kits/explainable_ai/venv/lib/python3.13/site-packages/openvino/runtime/__init__.py:10: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   warnings.warn(
# 0: 640x640 (no detections), 347.4ms
# Speed: 14.1ms preprocess, 347.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 353.6ms
# Speed: 10.5ms preprocess, 353.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 595.9ms
# Speed: 5.7ms preprocess, 595.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 607.1ms
# Speed: 4.5ms preprocess, 607.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 350.7ms
# Speed: 5.2ms preprocess, 350.7ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 344.9ms
# Speed: 18.1ms preprocess, 344.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 593.4ms
# Speed: 2.0ms preprocess, 593.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 589.7ms
# Speed: 4.1ms preprocess, 589.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 330.4ms
# Speed: 3.2ms preprocess, 330.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 328.5ms
# Speed: 1.4ms preprocess, 328.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 583.9ms
# Speed: 6.6ms preprocess, 583.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 584.1ms
# Speed: 4.7ms preprocess, 584.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 331.4ms
# Speed: 2.2ms preprocess, 331.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 329.5ms
# Speed: 1.5ms preprocess, 329.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 583.9ms
# Speed: 6.4ms preprocess, 583.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 (no detections), 584.7ms
# Speed: 6.9ms preprocess, 584.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 1 car, 327.6ms
# Speed: 6.3ms preprocess, 327.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 1 car, 331.4ms
# Speed: 4.3ms preprocess, 331.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# WARNING ⚠️ no tracks found!
#
# 0: 640x640 1 car, 590.0ms
# Speed: 3.5ms preprocess, 590.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 600.7ms
# Speed: 7.0ms preprocess, 600.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 333.7ms
# Speed: 5.0ms preprocess, 333.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 car, 341.5ms
# Speed: 5.1ms preprocess, 341.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 591.2ms
# Speed: 3.8ms preprocess, 591.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 587.3ms
# Speed: 4.0ms preprocess, 587.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 328.2ms
# Speed: 6.6ms preprocess, 328.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.3ms
# Speed: 1.4ms preprocess, 328.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 587.5ms
# Speed: 4.1ms preprocess, 587.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.7ms
# Speed: 5.7ms preprocess, 584.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.4ms
# Speed: 1.9ms preprocess, 329.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 327.9ms
# Speed: 5.1ms preprocess, 327.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.0ms
# Speed: 4.6ms preprocess, 584.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.2ms
# Speed: 5.0ms preprocess, 584.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.3ms
# Speed: 7.6ms preprocess, 328.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 327.9ms
# Speed: 4.1ms preprocess, 327.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 587.2ms
# Speed: 5.8ms preprocess, 587.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.5ms
# Speed: 5.1ms preprocess, 585.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.8ms
# Speed: 4.9ms preprocess, 328.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 331.0ms
# Speed: 4.1ms preprocess, 331.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 587.0ms
# Speed: 5.1ms preprocess, 587.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 588.3ms
# Speed: 10.1ms preprocess, 588.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.1ms
# Speed: 11.4ms preprocess, 329.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 330.0ms
# Speed: 3.8ms preprocess, 330.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.3ms
# Speed: 5.1ms preprocess, 585.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 586.8ms
# Speed: 4.9ms preprocess, 586.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.1ms
# Speed: 7.5ms preprocess, 329.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.5ms
# Speed: 4.2ms preprocess, 329.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 582.5ms
# Speed: 6.6ms preprocess, 582.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.1ms
# Speed: 6.5ms preprocess, 584.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 327.4ms
# Speed: 8.0ms preprocess, 327.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.6ms
# Speed: 2.4ms preprocess, 329.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 583.5ms
# Speed: 4.0ms preprocess, 583.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 583.0ms
# Speed: 6.6ms preprocess, 583.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 326.6ms
# Speed: 4.9ms preprocess, 326.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.5ms
# Speed: 7.1ms preprocess, 328.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.2ms
# Speed: 4.5ms preprocess, 585.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 583.9ms
# Speed: 9.1ms preprocess, 583.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 331.3ms
# Speed: 4.2ms preprocess, 331.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.6ms
# Speed: 7.3ms preprocess, 328.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 586.8ms
# Speed: 4.1ms preprocess, 586.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 583.8ms
# Speed: 5.6ms preprocess, 583.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 332.9ms
# Speed: 5.6ms preprocess, 332.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 332.6ms
# Speed: 6.2ms preprocess, 332.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.8ms
# Speed: 8.9ms preprocess, 585.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.9ms
# Speed: 8.2ms preprocess, 584.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 331.1ms
# Speed: 8.7ms preprocess, 331.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 328.6ms
# Speed: 5.0ms preprocess, 328.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.4ms
# Speed: 5.0ms preprocess, 584.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 584.5ms
# Speed: 5.6ms preprocess, 584.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.6ms
# Speed: 4.1ms preprocess, 329.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 332.3ms
# Speed: 8.1ms preprocess, 332.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 587.1ms
# Speed: 4.5ms preprocess, 587.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.1ms
# Speed: 5.3ms preprocess, 585.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 331.4ms
# Speed: 5.7ms preprocess, 331.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 329.4ms
# Speed: 6.7ms preprocess, 329.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 585.2ms
# Speed: 7.2ms preprocess, 585.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 593.4ms
# Speed: 8.9ms preprocess, 593.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 336.2ms
# Speed: 4.0ms preprocess, 336.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 338.9ms
# Speed: 4.7ms preprocess, 338.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 597.1ms
# Speed: 5.4ms preprocess, 597.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 598.2ms
# Speed: 9.5ms preprocess, 598.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 336.4ms
# Speed: 1.5ms preprocess, 336.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 336.5ms
# Speed: 5.9ms preprocess, 336.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 602.7ms
# Speed: 1.1ms preprocess, 602.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 597.5ms
# Speed: 12.5ms preprocess, 597.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 345.2ms
# Speed: 1.5ms preprocess, 345.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 cars, 342.9ms
# Speed: 6.6ms preprocess, 342.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# This snippet generates our heatmap for our optimized YOLOv8 model with the yellowish to blue areas indicating the focus of the model! Despite leveraging a model with smaller model size, we're still able to enable explainabiility for our optimized models.
#
# The generated output is a video - we include a sample snippet from the video below!

# %% [markdown]
# ![sample_snippet](https://github.com/openvinotoolkit/datumaro/assets/22090501/89ff7890-48c9-4e04-8b54-10bd9af4206f)

# %% [markdown]
# <img referrerpolicy="no-referrer-when-downgrade" src="https://static.scarf.sh/a.png?x-pxid=7003a37c-568d-40a5-9718-0d021d8589ca&project=ai_ref_kits/explainable_ai&file=explainable_ai.ipynb" />
